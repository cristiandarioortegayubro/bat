# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/bat/blob/main/capitulo_02/pandas_01_estructura_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estructura de datos

# %% [markdown]
# ## Carga de módulos necesarios

# %% [markdown]
# ### Para análisis de datos

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creación del dataframe

# %%
datos = "https://raw.githubusercontent.com/cristiandarioortegayubro/bat/main/datasets/anslisis_facturas_venta.csv"
df = pd.read_csv(datos)
